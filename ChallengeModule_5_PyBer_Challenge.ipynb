# %% [markdown]
# # Pyber Challenge

# %% [markdown]
# ### 4.3 Loading and Reading CSV files

# %%
# Add Matplotlib inline magic command
# %matplotlib inline
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd

# File to Load (Remember to change these)
city_data_to_load = "Resources/city_data.csv"
ride_data_to_load = "Resources/ride_data.csv"

# Read the City and Ride Data
city_data_df = pd.read_csv(city_data_to_load)
ride_data_df = pd.read_csv(ride_data_to_load)

# %%
city_data_df
# Out:
#                 city  driver_count   type
# 0        Richardfort            38  Urban
# 1       Williamsstad            59  Urban
# 2        Port Angela            67  Urban
# 3         Rodneyfort            34  Urban
# 4        West Robert            39  Urban
# ..               ...           ...    ...
# 115     Bradshawfurt             7  Rural
# 116     New Ryantown             2  Rural
# 117   Randallchester             9  Rural
# 118      Jessicaport             1  Rural
# 119  South Saramouth             7  Rural
#
# [120 rows x 3 columns]

# %%
ride_data_df
# Out:
#                     city                 date   fare        ride_id
# 0     Lake Jonathanshire  2019-01-14 10:14:22  13.83  5739410935873
# 1     South Michelleport  2019-03-04 18:24:09  30.24  2343912425577
# 2     Port Samanthamouth  2019-02-24 04:29:00  33.44  2005065760003
# 3             Rodneyfort  2019-02-10 23:22:03  23.44  5149245426178
# 4             South Jack  2019-03-06 04:28:35  34.58  3908451377344
# ...                  ...                  ...    ...            ...
# 2370         Michaelberg  2019-04-29 17:04:39  13.38  8550365057598
# 2371     Lake Latoyabury  2019-01-30 00:05:47  20.76  9018727594352
# 2372         North Jaime  2019-02-10 21:03:50  11.11  2781339863778
# 2373        West Heather  2019-05-07 19:22:15  44.94  4256853490277
# 2374          Newtonview  2019-04-25 10:20:13  55.84  9990581345298
#
# [2375 rows x 4 columns]

# %% [markdown]
# ### Merge the DataFrames

# %%
# Combine the data into a single dataset
pyber_data_df = pd.merge(ride_data_df, city_data_df, how="left", on=["city", "city"])

# Display the data table for preview
pyber_data_df.head()
# Out:
#                  city                 date   fare        ride_id  \
# 0  Lake Jonathanshire  2019-01-14 10:14:22  13.83  5739410935873
# 1  South Michelleport  2019-03-04 18:24:09  30.24  2343912425577
# 2  Port Samanthamouth  2019-02-24 04:29:00  33.44  2005065760003
# 3          Rodneyfort  2019-02-10 23:22:03  23.44  5149245426178
# 4          South Jack  2019-03-06 04:28:35  34.58  3908451377344
#
#    driver_count   type
# 0             5  Urban
# 1            72  Urban
# 2            57  Urban
# 3            34  Urban
# 4            46  Urban

# %%
#Not in the Challenge Requirements but adding to check the data
pyber_data_df.describe()
# Out:
#               fare       ride_id  driver_count
# count  2375.000000  2.375000e+03   2375.000000
# mean     26.753112  4.887270e+12     28.930105
# std      12.109465  2.907361e+12     20.666306
# min       4.050000  3.218337e+08      1.000000
# 25%      17.190000  2.381175e+12     11.000000
# 50%      26.600000  4.748541e+12     23.000000
# 75%      36.645000  7.461936e+12     45.000000
# max      58.550000  9.991538e+12     73.000000

# %%
#Not in the Challenge Requirements but adding to check the data
pyber_data_df.isna().sum()
# Out:
# city            0
# date            0
# fare            0
# ride_id         0
# driver_count    0
# type            0
# dtype: int64

# %% [markdown]
# ## Deliverable 1: Get a Summary DataFrame

# %%
#  1. Get the total rides for each city type
total_rides_city_type = pyber_data_df.groupby(['type']).count()['ride_id']
total_rides_city_type
# Out:
# type
# Rural        125
# Suburban     625
# Urban       1625
# Name: ride_id, dtype: int64

# %%
# 2. Get the total drivers for each city type
total_drivers_city_type = city_data_df.groupby(['type']).sum()['driver_count']
total_drivers_city_type
#using the city_data_df so the numbers match the printout in the instructions
#using pyber_data_df gave the following results: Rural 537; Suburban 8570; Urban 59602
# Out:
# type
# Rural         78
# Suburban     490
# Urban       2405
# Name: driver_count, dtype: int64

# %%
#  3. Get the total amount of fares for each city type
fares_by_city_type = pyber_data_df.groupby(['type']).sum()['fare']
fares_by_city_type
# Out:
# type
# Rural        4327.93
# Suburban    19356.33
# Urban       39854.38
# Name: fare, dtype: float64

# %%
#  4. Get the average fare per ride for each city type. 
avg_fare_by_city_type = fares_by_city_type / total_rides_city_type
avg_fare_by_city_type
# Out:
# type
# Rural       34.623440
# Suburban    30.970128
# Urban       24.525772
# dtype: float64

# %%
# 5. Get the average fare per driver for each city type. 
avg_fare_per_driver_city_type = fares_by_city_type / total_drivers_city_type
avg_fare_per_driver_city_type
# Out:
# type
# Rural       55.486282
# Suburban    39.502714
# Urban       16.571468
# dtype: float64

# %%
#  6. Create a PyBer summary DataFrame. 
pyber_summary_df = pd.DataFrame({'Total Rides': total_rides_city_type, 
                              'Total Drivers': total_drivers_city_type,
                              'Total Fares': fares_by_city_type,
                              'Average Fare per Ride': avg_fare_by_city_type,
                              'Average Fare per Driver': avg_fare_per_driver_city_type})
pyber_summary_df
# Out:
#           Total Rides  Total Drivers  Total Fares  Average Fare per Ride  \
# type
# Rural             125             78      4327.93              34.623440
# Suburban          625            490     19356.33              30.970128
# Urban            1625           2405     39854.38              24.525772
#
#           Average Fare per Driver
# type
# Rural                   55.486282
# Suburban                39.502714
# Urban                   16.571468

# %%
#  7. Cleaning up the DataFrame. Delete the index name
pyber_summary_df.index.name = None
pyber_summary_df
# Out:
#           Total Rides  Total Drivers  Total Fares  Average Fare per Ride  \
# Rural             125             78      4327.93              34.623440
# Suburban          625            490     19356.33              30.970128
# Urban            1625           2405     39854.38              24.525772
#
#           Average Fare per Driver
# Rural                   55.486282
# Suburban                39.502714
# Urban                   16.571468

# %%
#  8. Format the columns.
column_formats = {"Total Rides": "{:,}",
                  "Total Drivers": "{:,}",
                  "Total Fares": "${:,.2f}",
                  "Average Fare per Ride": "${:,.2f}",
                  "Average Fare per Driver":"${:,.2f}"}
pyber_summary_df = pyber_summary_df.style.format(column_formats)
pyber_summary_df
# Out:
# <style type="text/css">
# </style>
# <table id="T_ab121_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Total Rides</th>
#       <th class="col_heading level0 col1" >Total Drivers</th>
#       <th class="col_heading level0 col2" >Total Fares</th>
#       <th class="col_heading level0 col3" >Average Fare per Ride</th>
#       <th class="col_heading level0 col4" >Average Fare per Driver</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ab121_level0_row0" class="row_heading level0 row0" >Rural</th>
#       <td id="T_ab121_row0_col0" class="data row0 col0" >125</td>
#       <td id="T_ab121_row0_col1" class="data row0 col1" >78</td>
#       <td id="T_ab121_row0_col2" class="data row0 col2" >$4,327.93</td>
#       <td id="T_ab121_row0_col3" class="data row0 col3" >$34.62</td>
#       <td id="T_ab121_row0_col4" class="data row0 col4" >$55.49</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# ## Deliverable 2.  Create a multiple line plot that shows the total weekly of the fares for each type of city.

# %%
# 1. Read the merged DataFrame
pyber_data_df
# Out:
#                     city                 date   fare        ride_id  \
# 0     Lake Jonathanshire  2019-01-14 10:14:22  13.83  5739410935873
# 1     South Michelleport  2019-03-04 18:24:09  30.24  2343912425577
# 2     Port Samanthamouth  2019-02-24 04:29:00  33.44  2005065760003
# 3             Rodneyfort  2019-02-10 23:22:03  23.44  5149245426178
# 4             South Jack  2019-03-06 04:28:35  34.58  3908451377344
# ...                  ...                  ...    ...            ...
# 2370         Michaelberg  2019-04-29 17:04:39  13.38  8550365057598
# 2371     Lake Latoyabury  2019-01-30 00:05:47  20.76  9018727594352
# 2372         North Jaime  2019-02-10 21:03:50  11.11  2781339863778
# 2373        West Heather  2019-05-07 19:22:15  44.94  4256853490277
# 2374          Newtonview  2019-04-25 10:20:13  55.84  9990581345298
#
#       driver_count   type
# 0                5  Urban
# 1               72  Urban
# 2               57  Urban
# 3               34  Urban
# ...

# %%
# 2. Using groupby() to create a new DataFrame showing the sum of the fares 
#  for each date where the indices are the city type and date.
sum_of_fares_by_date_df = pyber_data_df.groupby(["type", "date"]).sum("fare")
sum_of_fares_by_date_df
# Out:
#                             fare        ride_id  driver_count
# type  date
# Rural 2019-01-01 09:45:36  43.69  2424875833354             1
#       2019-01-02 11:18:32  52.12  3454018971635             1
#       2019-01-03 19:51:01  19.90  5559509612597             8
#       2019-01-04 03:31:26  24.88  4195619112933             8
#       2019-01-06 07:38:40  47.33  3849747342021             4
# ...                          ...            ...           ...
# Urban 2019-05-08 04:20:00  21.99   117997692054            52
#       2019-05-08 04:39:49  18.45  1811574736337            11
#       2019-05-08 07:29:01  18.55  5682021476085            33
#       2019-05-08 11:38:35  19.77  7837163332630             4
#       2019-05-08 13:10:18  18.04  5616262558026            58
#
# [2375 rows x 3 columns]

# %%
# 3. Reset the index on the DataFrame you created in #1. This is needed to use the 'pivot()' function.
# df = df.reset_index()
sum_of_fares_by_date_df = sum_of_fares_by_date_df.reset_index()
sum_of_fares_by_date_df
# Out:
#        type                 date   fare        ride_id  driver_count
# 0     Rural  2019-01-01 09:45:36  43.69  2424875833354             1
# 1     Rural  2019-01-02 11:18:32  52.12  3454018971635             1
# 2     Rural  2019-01-03 19:51:01  19.90  5559509612597             8
# 3     Rural  2019-01-04 03:31:26  24.88  4195619112933             8
# 4     Rural  2019-01-06 07:38:40  47.33  3849747342021             4
# ...     ...                  ...    ...            ...           ...
# 2370  Urban  2019-05-08 04:20:00  21.99   117997692054            52
# 2371  Urban  2019-05-08 04:39:49  18.45  1811574736337            11
# 2372  Urban  2019-05-08 07:29:01  18.55  5682021476085            33
# 2373  Urban  2019-05-08 11:38:35  19.77  7837163332630             4
# 2374  Urban  2019-05-08 13:10:18  18.04  5616262558026            58
#
# [2375 rows x 5 columns]

# %%
# 4. Create a pivot table with the 'date' as the index, the columns ='type', and values='fare' 
# to get the total fares for each type of city by the date. 
pyber_pivot_table_df = pyber_data_df.pivot(index = "date", columns ="type", values="fare")
pyber_pivot_table_df.head(10)
# Out:
# type                 Rural  Suburban  Urban
# date
# 2019-01-01 00:08:16    NaN       NaN  37.91
# 2019-01-01 00:46:46    NaN     47.74    NaN
# 2019-01-01 02:07:24    NaN     24.07    NaN
# 2019-01-01 03:46:50    NaN       NaN   7.57
# 2019-01-01 05:23:21    NaN       NaN  10.75
# 2019-01-01 09:45:36  43.69       NaN    NaN
# 2019-01-01 12:32:48    NaN     25.56    NaN
# 2019-01-01 14:40:14    NaN       NaN   5.42
# 2019-01-01 14:42:25    NaN       NaN  12.31
# 2019-01-01 14:52:06    NaN     31.15    NaN

# %%
# 5. Create a new DataFrame from the pivot table DataFrame using loc on the given dates, '2019-01-01':'2019-04-29'.
pyber_pivot_table_loc_df = pyber_pivot_table_df.loc['2019-01-01':'2019-04-29']
pyber_pivot_table_loc_df.head(10)
# Out:
# type                 Rural  Suburban  Urban
# date
# 2019-01-01 00:08:16    NaN       NaN  37.91
# 2019-01-01 00:46:46    NaN     47.74    NaN
# 2019-01-01 02:07:24    NaN     24.07    NaN
# 2019-01-01 03:46:50    NaN       NaN   7.57
# 2019-01-01 05:23:21    NaN       NaN  10.75
# 2019-01-01 09:45:36  43.69       NaN    NaN
# 2019-01-01 12:32:48    NaN     25.56    NaN
# 2019-01-01 14:40:14    NaN       NaN   5.42
# 2019-01-01 14:42:25    NaN       NaN  12.31
# 2019-01-01 14:52:06    NaN     31.15    NaN

# %%
# 6. Set the "date" index to datetime datatype. This is necessary to use the resample() method in Step 8.
# df.index = pd.to_datetime(df.index)
pyber_pivot_table_loc_df.index = pd.to_datetime(pyber_pivot_table_loc_df.index)
pyber_pivot_table_loc_df
# Out:
# type                 Rural  Suburban  Urban
# date
# 2019-01-01 00:08:16    NaN       NaN  37.91
# 2019-01-01 00:46:46    NaN     47.74    NaN
# 2019-01-01 02:07:24    NaN     24.07    NaN
# 2019-01-01 03:46:50    NaN       NaN   7.57
# 2019-01-01 05:23:21    NaN       NaN  10.75
# ...                    ...       ...    ...
# 2019-04-28 14:28:36    NaN       NaN  11.46
# 2019-04-28 16:29:16    NaN       NaN  36.42
# 2019-04-28 17:26:52    NaN       NaN  31.43
# 2019-04-28 17:38:09    NaN     34.87    NaN
# 2019-04-28 19:35:03    NaN     16.96    NaN
#
# [2196 rows x 3 columns]

# %%
# 7. Check that the datatype for the index is datetime using df.info()
pyber_pivot_table_loc_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2196 entries, 2019-01-01 00:08:16 to 2019-04-28 19:35:03
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Rural     114 non-null    float64
#  1   Suburban  573 non-null    float64
#  2   Urban     1509 non-null   float64
# dtypes: float64(3)
# memory usage: 68.6 KB

# %%
# 8. Create a new DataFrame using the "resample()" function by week 'W' and get the sum of the fares for each week.
sum_of_fares_by_week_df = pyber_pivot_table_loc_df.resample('W').sum()
sum_of_fares_by_week_df.head(10)
# Out:
# type         Rural  Suburban    Urban
# date
# 2019-01-06  187.92    721.60  1661.68
# 2019-01-13   67.65   1105.13  2050.43
# 2019-01-20  306.00   1218.20  1939.02
# 2019-01-27  179.69   1203.28  2129.51
# 2019-02-03  333.08   1042.79  2086.94
# 2019-02-10  115.80    974.34  2162.64
# 2019-02-17   95.82   1045.50  2235.07
# 2019-02-24  419.06   1412.74  2466.29
# 2019-03-03  175.14    858.46  2218.20
# 2019-03-10  303.94    925.27  2470.93

# %%
# 8. Using the object-oriented interface method, plot the resample DataFrame using the df.plot() function. 

# Import the style from Matplotlib.
from matplotlib import style
# Use the graph style fivethirtyeight.
style.use('fivethirtyeight')

#Setting the Axes 
total_fares_by_city_type_graph = sum_of_fares_by_week_df.plot(figsize = (20,6))

#Labeling the Graph and the Axes
total_fares_by_city_type_graph.set_title('Total Fare by City Type')
total_fares_by_city_type_graph.set_xlabel('Months')
total_fares_by_city_type_graph.set_ylabel('Fare ($USD)')

#Additional Formatting for the Graph
total_fares_by_city_type_graph.grid(True)
plt.tight_layout()

plt.savefig("Analysis/total_fares_by_city_type_graph.png")

plt.show()
